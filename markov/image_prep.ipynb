# %%
from PIL import Image

# %%
swim = Image.open("../images/swim.jpg")
w,h = swim.size
scale =  (512/h)
resized=swim.resize(( int(w*scale),int( h*scale))).crop((0,0,512,512))

# %%
resized.save("./images/swim.512.png")
